# %% [markdown]
# # Visualization Demo
#
# This notebook opens the generated VTK dataset with PyVista. Run `python scripts/setup_case.py` first.

# %%
from pathlib import Path
import pyvista as pv

mesh = pv.read(Path('../data/processed/sample_car_flow.vtu'))
mesh

# %%
mesh.array_names

# %%
slice_y = mesh.slice(normal='y')
slice_y.plot(scalars='velocity_magnitude', cmap='viridis')

# %% [markdown]
# Use ParaView for richer interactive exploration: slices, streamlines, glyphs, contours, camera paths, and screenshot export.
